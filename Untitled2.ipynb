# %% [markdown]
# <a href="https://colab.research.google.com/github/rstuardoc/ay03-stuardo-rocio/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
#Bloc des imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Sachez que certain packages ont des datasets de sauvegardés!
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
